# %% [markdown]
# # Lab Activity Week 6
#
# **Homework** Anythin you do not complete in lab is your homework. Please provide a link to your github repository as your homework submission.

# %% [markdown]
# ### Step 1: Aquiring data
#
# - Collect data from your weather and air quality sensors together (in the same script) for 5 minutes, taking a reading every second.
# - Make the name of the file saving the data something that is unique each time data is recorded.
#    - **HINT:** You can include the time as part of the file name, for example.
# - Upload your new data to your git repository on GitHub and update the version of your respository on your laptop

# %% [markdown]
# ### Step 2: Acquiring outdoor data
# - Restart your raspberry pi system, powering it with the supplied batteries, rather than the power adaptor.
# - Add a time delay to the start of your data acquisition script (as an optional user input)
# - Start your data aquisition to again collect data for 5 minutes, taking readings every second, but this time with an initial ~2 minute delay (so it should run for ~7 minutes total).
# - Take the whole system outdoors and wait there for the 5 minutes of data acquisition to complete.
# - At your stations, again push your new data to your git repository on GitHub

# %% [markdown]
# ### Step 3: Plotting indoor data
# - Create a new Jupyter notebook and load (using pandas, for example) the data you now have from your device.
# - Plot each type of data as a frequency distribution (histogram) with appropriate binning - meaning the distribution shows a good level of detail but does not have binning artifacts
# - Using the mean and standard deviation of each set of data, does any of the data you have recorded look like it is well described by a normal distribution?
#   - Using the mean and standard deviation, try plotting a Gaussian function along with each of your frequency distributions and see how well they match.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import math

inside_data = pd.read_csv('inside_at_2-50pm_2-24-23.csv')
display(inside_data)
# Out:
#              Time  PM10  PM25  PM100       Temp    Gas  Relative Humidity  \
# 0    1.677279e+09     0     1      1  22.250312  95219          32.430740
# 1    1.677279e+09     0     1      1  22.269844  16856          32.471848
# 2    1.677279e+09     0     1      1  22.306758  20475          32.452616
# 3    1.677279e+09     0     1      1  22.342891  22254          32.410816
# 4    1.677279e+09     0     1      1  22.376875  24181          32.335098
# ..            ...   ...   ...    ...        ...    ...                ...
# 246  1.677279e+09     0     0      0  22.423359  38420          31.962991
# 247  1.677279e+09     0     0      0  22.426875  38420          31.946476
# 248  1.677279e+09     0     0      0  22.430195  38454          31.929946
# 249  1.677279e+09     0     0      0  22.434297  38622          31.907880
# 250  1.677279e+09     0     0      0  22.438789  38487          31.885851
#
#        Pressure    Altitude
# 0    996.185782  143.049899
# ...

# %%
# defining normal distribution curve function
def normal_dist(x , mean , sd):
    prob_density = np.exp(-0.5*((x-mean)/sd)**2)/(math.sqrt(2*np.pi)*sd)
    return prob_density

# %%
# PM10

x_pm10_in = inside_data["PM10"]

mean_pm10_in = np.mean(x_pm10_in)
std_pm10_in = np.std(x_pm10_in)

# x_norm = np.linspace(np.min(x),np.max(x),200)
# norm_dist = normal_dist(x_norm,mean,std)

plt.hist(x_pm10_in,bins=1, density=True)
# plt.plot(x_norm,norm_dist) cant plot normal distribution curve because std is zero
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# PM25

x_pm25_in = inside_data["PM25"]

mean_pm25_in = np.mean(x_pm25_in)
std_pm25_in = np.std(x_pm25_in)

x_norm_pm25_in = np.linspace(np.min(x_pm25_in),np.max(x_pm25_in),200)
norm_dist_pm25_in = normal_dist(x_norm_pm25_in,mean_pm25_in,std_pm25_in)

plt.hist(x_pm25_in,bins=2,density=True)
plt.plot(x_norm_pm25_in,norm_dist_pm25_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# PM100

x_pm100_in = inside_data["PM100"]

mean_pm100_in = np.mean(x_pm100_in)
std_pm100_in = np.std(x_pm100_in)

x_norm_pm100_in = np.linspace(np.min(x_pm100_in),np.max(x_pm100_in),200)
norm_dist_pm100_in = normal_dist(x_norm_pm100_in,mean_pm100_in,std_pm100_in)

plt.hist(x_pm100_in, bins=2, density=True)
plt.plot(x_norm_pm100_in,norm_dist_pm100_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Temp

x_temp_in = inside_data["Temp"]

mean_temp_in = np.mean(x_temp_in)
std_temp_in = np.std(x_temp_in)

x_norm_temp_in = np.linspace(np.min(x_temp_in),np.max(x_temp_in),200)
norm_dist_temp_in = normal_dist(x_norm_temp_in,mean_temp_in,std_temp_in)

plt.hist(x_temp_in,bins=50,density=True)
plt.plot(x_norm_temp_in,norm_dist_temp_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Gas

x_gas_in = inside_data["Gas"]

mean_gas_in = np.mean(x_gas_in)
std_gas_in = np.std(x_gas_in)

x_norm_gas_in = np.linspace(np.min(x_gas_in),np.max(x_gas_in),200)
norm_dist_gas_in = normal_dist(x_norm_gas_in,mean_gas_in,std_gas_in)

plt.hist(x_gas_in,bins=40,density=True)
plt.plot(x_norm_gas_in,norm_dist_gas_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Relative Humidity

x_hum_in = inside_data["Relative Humidity"]

mean_hum_in = np.mean(x_hum_in)
std_hum_in = np.std(x_hum_in)

x_norm_hum_in = np.linspace(np.min(x_hum_in),np.max(x_hum_in),200)
norm_dist_hum_in = normal_dist(x_norm_hum_in,mean_hum_in,std_hum_in)

plt.hist(x_hum_in,bins=20,density=True)
plt.plot(x_norm_hum_in,norm_dist_hum_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Pressure

x_press_in = inside_data["Pressure"]

mean_press_in = np.mean(x_press_in)
std_press_in = np.std(x_press_in)

x_norm_press_in = np.linspace(np.min(x_press_in),np.max(x_press_in),200)
norm_dist_press_in = normal_dist(x_norm_press_in,mean_press_in,std_press_in)

plt.hist(x_press_in,bins=40,density=True)
plt.plot(x_norm_press_in,norm_dist_press_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Altitude

x_alt_in = inside_data["Altitude"]

mean_alt_in = np.mean(x_alt_in)
std_alt_in = np.std(x_alt_in)

x_norm_alt_in = np.linspace(np.min(x_alt_in),np.max(x_alt_in),200)
norm_dist_alt_in = normal_dist(x_norm_alt_in,mean_alt_in,std_alt_in)

plt.hist(x_alt_in,bins=40,density=True)
plt.plot(x_norm_alt_in,norm_dist_alt_in)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# ### Step 4: Comparing Indoor vs Outdoor data
# - Produce the same plots as in Step 2 for your new outdoor data
# - Now produce plots that compare indoors vs outdoors for each of your data types - don't forget labels
# - Comment on your results
# - Compare the mean and standard deviation values for each set of indoor data versus outdoor data, are they in agreement?
#   - NOTE: The variance in your data is not the uncertainty on the mean (central limit theorem)
#   - what is your mean uncertainty?
#   - How many inside mean standard deviations (1 sigma uncertainty) are your inside and outside measurements separated by?
# - If your distributions were not well described by a Gaussian, do you think you took enough data for the central limit theorem to apply?

# %%
outside_data = pd.read_csv('outside_at_3-02_2-24-23.csv')
outside_data = outside_data[100:351]
display(outside_data)
# Out:
#              Time  PM10  PM25  PM100       Temp    Gas  Relative Humidity  \
# 100  1.677280e+09     0     0      0  18.855195  44688          33.729734
# 101  1.677280e+09     0     0      0  18.748750  44688          33.759796
# 102  1.677280e+09     0     0      0  18.667500  44824          33.803389
# 103  1.677280e+09     0     0      0  18.591719  45191          33.813599
# 104  1.677280e+09     0     0      0  18.509492  45007          33.817594
# ..            ...   ...   ...    ...        ...    ...                ...
# 346  1.677280e+09     2     4      6  13.879023  54542          46.425246
# 347  1.677280e+09     2     4      6  13.891719  54644          46.493536
# 348  1.677280e+09     2     4      6  13.906758  54712          46.549939
# 349  1.677280e+09     2     4      6  13.921797  54678          46.600276
# 350  1.677280e+09     2     4      6  13.934102  55157          46.625974
#
#        Pressure    Altitude
# 100  995.420576  149.510990
# ...

# %%
# Outside PM10

x_pm10_out = outside_data["PM10"]

mean_pm10_out = np.mean(x_pm10_out)
std_pm10_out = np.std(x_pm10_out)

x_norm_pm10_out = np.linspace(np.min(x_pm10_out),np.max(x_pm10_out),200)
norm_dist_pm10_out = normal_dist(x_norm_pm10_out,mean_pm10_out,std_pm10_out)

plt.hist(x_pm10_out,bins=6, density=True)
plt.plot(x_norm_pm10_out,norm_dist_pm10_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside PM25

x_pm25_out = outside_data["PM25"]

mean_pm25_out = np.mean(x_pm25_out)
std_pm25_out = np.std(x_pm25_out)

x_norm_pm25_out = np.linspace(np.min(x_pm25_out),np.max(x_pm25_out),200)
norm_dist_pm25_out = normal_dist(x_norm_pm25_out,mean_pm25_out,std_pm25_out)

plt.hist(x_pm25_out,bins=2,density=True)
plt.plot(x_norm_pm25_out,norm_dist_pm25_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside PM100

x_pm100_out = outside_data["PM100"]

mean_pm100_out = np.mean(x_pm100_out)
std_pm100_out = np.std(x_pm100_out)

x_norm_pm100_out = np.linspace(np.min(x_pm100_out),np.max(x_pm100_out),200)
norm_dist_pm100_out = normal_dist(x_norm_pm100_out,mean_pm100_in,std_pm100_out)

plt.hist(x_pm100_out, bins=2, density=True)
plt.plot(x_norm_pm100_out,norm_dist_pm100_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside Temp

x_temp_out = outside_data["Temp"]

mean_temp_out = np.mean(x_temp_out)
std_temp_out = np.std(x_temp_out)

x_norm_temp_out = np.linspace(np.min(x_temp_out),np.max(x_temp_out),200)
norm_dist_temp_out = normal_dist(x_norm_temp_out,mean_temp_out,std_temp_out)

plt.hist(x_temp_out,bins=50,density=True)
plt.plot(x_norm_temp_out,norm_dist_temp_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside Gas

x_gas_out = outside_data["Gas"]

mean_gas_out = np.mean(x_gas_out)
std_gas_out = np.std(x_gas_out)

x_norm_gas_out = np.linspace(np.min(x_gas_out),np.max(x_gas_out),200)
norm_dist_gas_out = normal_dist(x_norm_gas_out,mean_gas_out,std_gas_out)

plt.hist(x_gas_out,bins=40,density=True)
plt.plot(x_norm_gas_out,norm_dist_gas_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside Humidity

x_hum_out = outside_data["Relative Humidity"]

mean_hum_out = np.mean(x_hum_out)
std_hum_out = np.std(x_hum_out)

x_norm_hum_out = np.linspace(np.min(x_hum_out),np.max(x_hum_out),200)
norm_dist_hum_out = normal_dist(x_norm_hum_out,mean_hum_out,std_hum_out)

plt.hist(x_hum_out,bins=20,density=True)
plt.plot(x_norm_hum_out,norm_dist_hum_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside Pressure

x_press_out = outside_data["Pressure"]

mean_press_out = np.mean(x_press_out)
std_press_out = np.std(x_press_out)

x_norm_press_out = np.linspace(np.min(x_press_out),np.max(x_press_out),200)
norm_dist_press_out = normal_dist(x_norm_press_out,mean_press_out,std_press_out)

plt.hist(x_press_out,bins=40,density=True)
plt.plot(x_norm_press_out,norm_dist_press_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Outside Altitude

x_alt_out = outside_data["Altitude"]

mean_alt_out = np.mean(x_alt_out)
std_alt_out = np.std(x_alt_out)

x_norm_alt_out = np.linspace(np.min(x_alt_out),np.max(x_alt_out),200)
norm_dist_alt_out = normal_dist(x_norm_alt_out,mean_alt_out,std_alt_out)

plt.hist(x_alt_out,bins=40,density=True)
plt.plot(x_norm_alt_out,norm_dist_alt_out)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Inside vs Outside PM10
x = x_pm10_in
y = x_pm10_out

mean_diff = round(abs(mean_pm10_in - mean_pm10_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(0-std_pm10_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=1, alpha=0.5, label='inside')
plt.hist(y, bins=6, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('PM10')
plt.show()
# Out:
# The means differ by 1.16
# The stds differ by 1.71

# %%
# Inside vs Outside PM25
x = x_pm25_in
y = x_pm25_out

mean_diff = round(abs(mean_pm25_in - mean_pm25_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_pm25_in-std_pm25_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=2, alpha=0.5, label='inside')
plt.hist(y, bins=8, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('PM25')
plt.show()
# Out:
# The means differ by 1.77
# The stds differ by 2.15

# %%
# Inside vs Outside PM100
x = x_pm100_in
y = x_pm100_out

mean_diff = round(abs(mean_pm100_in - mean_pm100_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_pm100_in-std_pm100_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=2, alpha=0.5, label='inside')
plt.hist(y, bins=8, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('PM100')
plt.show()
# Out:
# The means differ by 2.03
# The stds differ by 2.17

# %%
# Inside vs Outside Temp
x = x_temp_in
y = x_temp_out

mean_diff = round(abs(mean_temp_in - mean_temp_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_temp_in-std_temp_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=4, alpha=0.5, label='inside')
plt.hist(y, bins=50, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('Temp')
plt.show()
# Out:
# The means differ by 8.33
# The stds differ by 1.48

# %%
# Inside vs Outside Gas
x = x_gas_in
y = x_gas_out

mean_diff = round(abs(mean_gas_in - mean_gas_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_gas_in-std_gas_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=40, alpha=0.5, label='inside')
plt.hist(y, bins=8, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('Gas')
plt.show()
# Out:
# The means differ by 17960.75
# The stds differ by 2460.02

# %%
# Inside vs Outside Hum
x = x_hum_in
y = x_hum_out

mean_diff = round(abs(mean_hum_in - mean_hum_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_hum_in-std_hum_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=8, alpha=0.5, label='inside')
plt.hist(y, bins=40, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('Relative Humidity')
plt.show()
# Out:
# The means differ by 11.65
# The stds differ by 3.77

# %%
# Inside vs Outside Pressure
x = x_press_in
y = x_press_out

mean_diff = round(abs(mean_press_in - mean_press_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_press_in-std_press_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=10, alpha=0.5, label='inside')
plt.hist(y, bins=10, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('Pressure')
plt.show()
# Out:
# The means differ by 0.73
# The stds differ by 0.0

# %%
# Inside vs Outside Alt
x = x_alt_in
y = x_alt_out

mean_diff = round(abs(mean_alt_in - mean_alt_out),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_alt_in-std_alt_out),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=8, alpha=0.5, label='inside')
plt.hist(y, bins=8, alpha=0.5, label='outside')
plt.legend(loc='upper right')
plt.title('Altitude')
plt.show()
# Out:
# The means differ by 6.18
# The stds differ by 0.04

# %% [markdown]
# ### Step 5: Comparing sensors
# - Get data from another group in your lab and compare your inside data with their inside data, including all of elements from Step 4. Do the same comparing your outside data with their outside data.
# - How do the sensors compare? What do you think this indicates about the accuracy and precision of your sensors?

# %% [markdown]
# The differences in the sensors' means and stds will tell us something about their relative accuracy and precision. If the means are relatively close then it means that they are relatively accurate. If their stds are relatively close then it shows that the precision of the sensor is relatively good. We can't know how accurate a specific sensor is unless we compare it to a sensor with a known accuracy, however we can tell that the precision is good by just how small the standard deviation is. We compared the sensors' accuracy and precision using the differences in the means and stds for the temperature to the altitude measurements. We only discussed the accuracy and precision of the sensors for the inside temperature measurements to the inside altitude measurements as it was very repetitive and feel that we got the point across for how the means and stds say something about the accuracy and precision. The descriptions for those are below each plot.

# %%
other_groups_inside_data = pd.read_csv('data.csv')
display(other_groups_inside_data)

other_groups_outside_data = pd.read_csv('outside_data.csv')
other_groups_outside_data = other_groups_outside_data[100:351]
display(other_groups_outside_data)
# Out:
#            Time  pm10_standard  pm25_standard  pm100_standard  Temperature  \
# 0    1677278929              0              0               0    22.490742
# 1    1677278930              0              0               0    22.505586
# 2    1677278931              0              0               0    22.537422
# 3    1677278933              0              0               0    22.565352
# 4    1677278934              0              0               0    22.587422
# ..          ...            ...            ...             ...          ...
# 247  1677279224              0              0               0    22.187031
# 248  1677279225              0              0               0    22.186250
# 249  1677279226              0              0               0    22.185273
# 250  1677279227              0              0               0    22.182734
# 251  1677279228              0              0               0    22.180391
#
#         Gas   Humidity    Pressure    Altitude
# ...

# %%
# Our's vs Other Group's Inside PM10 
x = x_pm10_in
y = other_groups_inside_data['pm10_standard']

plt.hist(x, bins=1, alpha=0.5, label='Our Group')
plt.hist(y, bins=1, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside PM10')
plt.show()

# %%
# Our's vs Other Group's Inside PM25 
x = x_pm25_in
y = other_groups_inside_data['pm25_standard']

plt.hist(x, bins=2, alpha=0.5, label='Our Group')
plt.hist(y, bins=2, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside PM25')
plt.show()

# %%
# Our's vs Other Group's Inside PM100 
x = x_pm100_in
y = other_groups_inside_data['pm100_standard']

plt.hist(x, bins=2, alpha=0.5, label='Our Group')
plt.hist(y, bins=2, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside PM100')
plt.show()

# %%
# Our's vs Other Group's Inside Temperature 
x = x_temp_in
y = other_groups_inside_data['Temperature']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=12, alpha=0.5, label='Our Group')
plt.hist(y, bins=12, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside Temperature')
plt.show()
# Out:
# The means differ by 0.13
# The stds differ by 0.01

# %% [markdown]
# Both the means and stds of each sensors' temp measurements are relatively close so we can conclude that they have relatively similar precision and accuracy. We can conclude that the sensor is relatively reliable.

# %%
# Our's vs Other Group's Inside Gas 
x = x_gas_in
y = other_groups_inside_data['Gas']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=5, alpha=0.5, label='Our Group')
plt.hist(y, bins=5, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside Gas')
plt.show()
# Out:
# The means differ by 86822.07
# The stds differ by 40857.85

# %% [markdown]
# The means and stds of the sensors' gas measurements are wildly different meaning that both their accuracy and precision are not so great. This sensor is not so reliable.

# %%
# Our's vs Other Group's Inside Humidity 
x = x_hum_in
y = other_groups_inside_data['Humidity']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=3, alpha=0.5, label='Our Group')
plt.hist(y, bins=3, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside Humidity')
plt.show()
# Out:
# The means differ by 2.06
# The stds differ by 0.41

# %% [markdown]
# The mean differs substancially more than the stds for the humidity measurements so we can say that the sensors' accuracy is not so good but the precision is relatively good.

# %%
# Our's vs Other Group's Inside Pressure 
x = x_press_in
y = other_groups_inside_data['Pressure']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=5, alpha=0.5, label='Our Group')
plt.hist(y, bins=5, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside Pressure')
plt.show()
# Out:
# The means differ by 0.69
# The stds differ by 0.0

# %% [markdown]
# The means differ much more than the stds differ because the stds dont differ at all. The accuracy of this sensor might be poor but the precision seems reliable.

# %%
# Our's vs Other Group's Inside Altitude 
x = x_alt_in
y = other_groups_inside_data['Altitude']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=7, alpha=0.5, label='Our Group')
plt.hist(y, bins=7, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Inside Altitude')
plt.show()
# Out:
# The means differ by 5.85
# The stds differ by 0.0

# %% [markdown]
# Similar to the pressure sensor the altitude sensor is maybe not so accurate but the precision seems relatively good.

# %%
# Our's vs Other Group's Outside PM10 
x = x_pm10_out
y = other_groups_outside_data['pm10_standard']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=1, alpha=0.5, label='Our Group')
plt.hist(y, bins=1, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside PM10')
plt.show()
# Out:
# The means differ by 0.03
# The stds differ by 0.65

# %%
# Our's vs Other Group's Outside PM25 
x = x_pm25_out
y = other_groups_outside_data['pm25_standard']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=3, alpha=0.5, label='Our Group')
plt.hist(y, bins=3, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside PM25')
plt.show()
# Out:
# The means differ by 0.41
# The stds differ by 0.49

# %%
# Our's vs Other Group's Outside PM100 
x = x_pm100_out
y = other_groups_outside_data['pm100_standard']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=3, alpha=0.5, label='Our Group')
plt.hist(y, bins=3, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside PM100')
plt.show()
# Out:
# The means differ by 0.09
# The stds differ by 0.7

# %%
# Our's vs Other Group's Outside Temperature 
x = x_temp_out
y = other_groups_outside_data['Temperature']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=12, alpha=0.5, label='Our Group')
plt.hist(y, bins=12, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside Temperature')
plt.show()
# Out:
# The means differ by 5.74
# The stds differ by 0.86

# %%
# Our's vs Other Group's Outside Gas 
x = x_gas_out
y = other_groups_outside_data['Gas']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=3, alpha=0.5, label='Our Group')
plt.hist(y, bins=12, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside Gas')
plt.show()
# Out:
# The means differ by 186331.02
# The stds differ by 15498.34

# %%
# Our's vs Other Group's Outside Humidity 
x = x_hum_out
y = other_groups_outside_data['Humidity']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=3, alpha=0.5, label='Our Group')
plt.hist(y, bins=3, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside Humidity')
plt.show()
# Out:
# The means differ by 13.84
# The stds differ by 3.61

# %%
# Our's vs Other Group's Outside Pressure 
x = x_press_out
y = other_groups_outside_data['Pressure']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=5, alpha=0.5, label='Our Group')
plt.hist(y, bins=5, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside Pressure')
plt.show()
# Out:
# The means differ by 1.21
# The stds differ by 0.06

# %%
# Our's vs Other Group's Outside Altitude 
x = x_alt_out
y = other_groups_outside_data['Altitude']

mean_our = np.mean(x)
std_our = np.std(x)
mean_other = np.mean(y)
std_other = np.std(y)

mean_diff = round(abs(mean_other - mean_our),2)
print('The means differ by {}'.format(mean_diff))
std_diff = round(abs(std_other-std_our),2)
print('The stds differ by {}'.format(std_diff))

plt.hist(x, bins=3, alpha=0.5, label='Our Group')
plt.hist(y, bins=7, alpha=0.5, label='Other Group')
plt.legend(loc='upper right')
plt.title('Outside Altitude')
plt.show()
# Out:
# The means differ by 10.23
# The stds differ by 0.51

# %% [markdown]
# ### Extra: Correlations in data
# - Plot temperature vs humidity
#   - NOTE: These were taken by the same sensor at the same time, so each measurement matches up in time, meaning plotting one versus the other works.
#   - What is the hidden variable that is important when making plots like this?
# - What does this plot show? Are temperature and humidity correlated? How might you quantify this?
#
# - Plot temperature vs another property measured by that sensor, are they correlated? Is the correlation qualitatively similar to what you see from temperature vs humidity?
#   - try this for all data types (temp. vs pressure, temp. vs voc, etc.)
#
# - Plot temperature vs PM2.5 concentration and discuss as with the previous comparisons.
